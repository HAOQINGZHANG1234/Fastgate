# %%
import numpy as np
from scipy.optimize import fsolve

# %matplotlib notebook
# %matplotlib inline

import matplotlib.pyplot as plt
# print(plt.style.available)  # show available template
plt.style.use(['seaborn-ticks','seaborn-paper'])  # use a templet

import matplotlib as mpl
# mpl.rcParams['lines.linewidth'] = 2
# mpl.rcParams['lines.color'] = 'r'
params = {
    'figure.figsize': [8, 6], # Note! figure unit is inch!  scale fontz size 2.54 to looks like unit cm
    'axes.labelsize': 7*2.54, # scale 2.54 to change to figure unit looks as cm
    'font.size':  7*2.54,
    'lines.linewidth':2,
    'legend.fontsize': 7*2.54,
    'xtick.labelsize': 6*2.54,
    'ytick.labelsize': 6*2.54,
    'text.usetex': False,  
    'xtick.direction': "in",
    'ytick.direction': "in", # ticket inside
    'legend.frameon' : True, 
    'legend.edgecolor': 'black',
    'legend.shadow': True,
    'legend.framealpha':1,
#     'patch.linewidth' : 0.5, 
}
mpl.rcParams.update(params)

# %% [markdown]
# # 利用符号系统计算定积分

# %%
from sympy import *
init_printing()

# %%
T0,T1,T2,T3,v,t1,t2, u,t,phi = symbols('T0,T1,T2,T3,v,t1,t2,u,tau,phi',real=True,positive=True)

# %%
# Geometric phase 函数， 积分矩阵的对角， 其中phi=phi1-phi2， 是相位分段函数构造的矩阵

A = integrate(cos(u*(t2-t1)+phi)*sin(v*(t2-t1)),(t1,T0,t2))
A = simplify(A)
A = integrate(A,(t2,T0,T1))

simplify(A)
# Out:
# ⎧    2                3              2                3           2
# ⎪T₀⋅u ⋅v⋅cos(φ) - T₀⋅v ⋅cos(φ) - T₁⋅u ⋅v⋅cos(φ) + T₁⋅v ⋅cos(φ) + u ⋅sin(v⋅(T₀
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎨
# ⎪
# ⎪                                                -2⋅T₀⋅v⋅(T₀⋅v⋅sin(φ) + cos(φ)
# ⎪                                                ─────────────────────────────
# ⎪
# ⎩
#
#
# - T₁))⋅cos(-T₀⋅u + T₁⋅u + φ) - 2⋅u⋅v⋅sin(φ) + 2⋅u⋅v⋅sin(-T₀⋅u + T₁⋅u + φ)⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#                                  2
#                         ⎛ 2    2⎞
#                         ⎝u  - v ⎠
#
# ) + 2⋅T₁⋅v⋅(2⋅T₀⋅v⋅sin(φ) - T₁⋅v⋅sin(φ) + cos(φ)) + sin(φ) - sin(-2⋅T₀⋅v + 2⋅T
# ──────────────────────────────────────────────────────────────────────────────
#                               2
#                            8⋅v
#
#                 2
# v⋅(T₀ - T₁)) + v ⋅sin(v⋅(T₀ - T₁))⋅cos(-T₀⋅u + T₁⋅u + φ)
# ────────────────────────────────────────────────────────  for u ≠ v
#
#
#
#
# ₁⋅v + φ)
# ────────                                                  otherwise

# %%
print(python(simplify(A)))
# Out:
# T0 = Symbol('T0')
# u = Symbol('u')
# v = Symbol('v')
# phi = Symbol('phi')
# T1 = Symbol('T1')
# e = Piecewise(((T0*u**2*v*cos(phi) - T0*v**3*cos(phi) - T1*u**2*v*cos(phi) + T1*v**3*cos(phi) + u**2*sin(v*(T0 - T1))*cos(-T0*u + T1*u + phi) - 2*u*v*sin(phi) + 2*u*v*sin(-T0*u + T1*u + phi)*cos(v*(T0 - T1)) + v**2*sin(v*(T0 - T1))*cos(-T0*u + T1*u + phi))/(u**2 - v**2)**2, Ne(u, v)), ((-2*T0*v*(T0*v*sin(phi) + cos(phi)) + 2*T1*v*(2*T0*v*sin(phi) - T1*v*sin(phi) + cos(phi)) + sin(phi) - sin(-2*T0*v + 2*T1*v + phi))/(8*v**2), true))

# %%
#  Geometric phase 函数， 积分矩阵的Fei对角， 其中phi=phi1-phi2， 是相位分段函数构造的矩阵

A = integrate(cos(u*(t2-t1)+phi)*sin(v*(t2-t1)),(t1,T0,T1))
A = simplify(A)
A = integrate(A,(t2,T2,T3))

simplify(A)
# Out:
# ⎧   2                                           2
# ⎪- u ⋅sin(v⋅(T₀ - T₂))⋅cos(-T₀⋅u + T₂⋅u + φ) + u ⋅sin(v⋅(T₀ - T₃))⋅cos(-T₀⋅u +
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎨
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎩
#
#               2                                           2
#  T₃⋅u + φ) + u ⋅sin(v⋅(T₁ - T₂))⋅cos(-T₁⋅u + T₂⋅u + φ) - u ⋅sin(v⋅(T₁ - T₃))⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
# os(-T₁⋅u + T₃⋅u + φ) - 2⋅u⋅v⋅sin(-T₀⋅u + T₂⋅u + φ)⋅cos(v⋅(T₀ - T₂)) + 2⋅u⋅v⋅si
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                         2                          2
#                                 - 4⋅T₂⋅v ⋅(T₀ - T₁)⋅sin(φ) + 4⋅T₃⋅v ⋅(T₀ - T₁)
#                                 ──────────────────────────────────────────────
#
#
#
#
#
# n(-T₀⋅u + T₃⋅u + φ)⋅cos(v⋅(T₀ - T₃)) + 2⋅u⋅v⋅sin(-T₁⋅u + T₂⋅u + φ)⋅cos(v⋅(T₁ -
# ──────────────────────────────────────────────────────────────────────────────
#                                          2
#                                 ⎛ 2    2⎞
#                                 ⎝u  - v ⎠
#
#
# ⋅sin(φ) + sin(-2⋅T₀⋅v + 2⋅T₂⋅v + φ) - sin(-2⋅T₀⋅v + 2⋅T₃⋅v + φ) - sin(-2⋅T₁⋅v
# ──────────────────────────────────────────────────────────────────────────────
#                                       2
#                                    8⋅v
#
#
#                                                         2
#  T₂)) - 2⋅u⋅v⋅sin(-T₁⋅u + T₃⋅u + φ)⋅cos(v⋅(T₁ - T₃)) - v ⋅sin(v⋅(T₀ - T₂))⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# + 2⋅T₂⋅v + φ) + sin(-2⋅T₁⋅v + 2⋅T₃⋅v + φ)
# ─────────────────────────────────────────
#
#
#
#
#                       2                                           2
# (-T₀⋅u + T₂⋅u + φ) + v ⋅sin(v⋅(T₀ - T₃))⋅cos(-T₀⋅u + T₃⋅u + φ) + v ⋅sin(v⋅(T₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                 2
# - T₂))⋅cos(-T₁⋅u + T₂⋅u + φ) - v ⋅sin(v⋅(T₁ - T₃))⋅cos(-T₁⋅u + T₃⋅u + φ)
# ────────────────────────────────────────────────────────────────────────  for
#
#
#
#
#
#
#                                                                           othe
#
#
#
#
#
#
# u ≠ v
#
#
#
#
#
#
# rwise

# %%
print(python(simplify(A)))
# Out:
# u = Symbol('u')
# v = Symbol('v')
# T0 = Symbol('T0')
# T2 = Symbol('T2')
# phi = Symbol('phi')
# T3 = Symbol('T3')
# T1 = Symbol('T1')
# e = Piecewise(((-u**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + u**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + u**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - u**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi) - 2*u*v*sin(-T0*u + T2*u + phi)*cos(v*(T0 - T2)) + 2*u*v*sin(-T0*u + T3*u + phi)*cos(v*(T0 - T3)) + 2*u*v*sin(-T1*u + T2*u + phi)*cos(v*(T1 - T2)) - 2*u*v*sin(-T1*u + T3*u + phi)*cos(v*(T1 - T3)) - v**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + v**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + v**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - v**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi))/(u**2 - v**2)**2, Ne(u, v)), ((-4*T2*v**2*(T0 - T1)*sin(phi) + 4*T3*v**2*(T0 - T1)*sin(phi) + sin(-2*T0*v + 2*T2*v + phi) - sin(-2*T0*v + 2*T3*v + phi) - sin(-2*T1*v + 2*T2*v + phi) + sin(-2*T1*v + 2*T3*v + phi))/(8*v**2), true))

# %%
#  Geometric phase 函数， 积分矩阵的对角， 其中phi=phi1-phi1=0， 是相位分段函数构造的矩阵

A = integrate(cos(u*(t2-t1))*sin(v*(t2-t1)),(t1,T0,t2))
A = simplify(A)
A = integrate(A,(t2,T0,T1))

simplify(A)
# Out:
# ⎧    2         3       2         3    2
# ⎪T₀⋅u ⋅v - T₀⋅v  - T₁⋅u ⋅v + T₁⋅v  + u ⋅sin(v⋅(T₀ - T₁))⋅cos(u⋅(T₀ - T₁)) - 2⋅
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪                                                                        ⎛ 2
# ⎨                                                                        ⎝u  -
# ⎪
# ⎪                                                          -2⋅T₀⋅v + 2⋅T₁⋅v +
# ⎪                                                          ───────────────────
# ⎪
# ⎩                                                                           8⋅
#
#                                          2
# u⋅v⋅sin(u⋅(T₀ - T₁))⋅cos(v⋅(T₀ - T₁)) + v ⋅sin(v⋅(T₀ - T₁))⋅cos(u⋅(T₀ - T₁))
# ────────────────────────────────────────────────────────────────────────────
#     2
#   2⎞
#  v ⎠
#
# sin(2⋅v⋅(T₀ - T₁))
# ──────────────────
#  2
# v
#
#
#
# for u ≠ v
#
#
#
#
#
# otherwise

# %%
print(python(simplify(A)))
# Out:
# T0 = Symbol('T0')
# u = Symbol('u')
# v = Symbol('v')
# T1 = Symbol('T1')
# e = Piecewise(((T0*u**2*v - T0*v**3 - T1*u**2*v + T1*v**3 + u**2*sin(v*(T0 - T1))*cos(u*(T0 - T1)) - 2*u*v*sin(u*(T0 - T1))*cos(v*(T0 - T1)) + v**2*sin(v*(T0 - T1))*cos(u*(T0 - T1)))/(u**2 - v**2)**2, Ne(u, v)), ((-2*T0*v + 2*T1*v + sin(2*v*(T0 - T1)))/(8*v**2), true))

# %%
#  Rubusty 函数， 积分矩阵的非对角， 其中phi=phi1+phi2， 是相位分段函数构造的矩阵
#  实部： 设置 phi=phi即可
#  虚部： 这只 phi = phi + pi/2 即可


A = integrate(cos(u*(t2+t1)+phi)*sin(v*(t2-t1)),(t1,T0,T1))
A = simplify(A)
A = integrate(A,(t2,T2,T3))

simplify(A)
# Out:
# ⎧    sin(v⋅(T₀ - T₂))⋅cos(T₀⋅u + T₂⋅u + φ) - sin(v⋅(T₀ - T₃))⋅cos(T₀⋅u + T₃⋅u
# ⎪    ─────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎨
# ⎪-T₀⋅cos(2⋅T₂⋅v + φ) + T₀⋅cos(2⋅T₃⋅v + φ) + T₁⋅cos(2⋅T₂⋅v + φ) - T₁⋅cos(2⋅T₃⋅v
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎩
#
# + φ) - sin(v⋅(T₁ - T₂))⋅cos(T₁⋅u + T₂⋅u + φ) + sin(v⋅(T₁ - T₃))⋅cos(T₁⋅u + T₃⋅
# ──────────────────────────────────────────────────────────────────────────────
#    2    2
#   u  - v
#
#  + φ) + T₂⋅cos(2⋅T₀⋅v + φ) - T₂⋅cos(2⋅T₁⋅v + φ) - T₃⋅cos(2⋅T₀⋅v + φ) + T₃⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#     4⋅v
#
#
# u + φ)
# ──────       for u ≠ v
#
#
#
# 2⋅T₁⋅v + φ)
# ───────────  otherwise

# %%
print(python(simplify(A)))
# Out:
# v = Symbol('v')
# T0 = Symbol('T0')
# T2 = Symbol('T2')
# u = Symbol('u')
# phi = Symbol('phi')
# T3 = Symbol('T3')
# T1 = Symbol('T1')
# e = Piecewise(((sin(v*(T0 - T2))*cos(T0*u + T2*u + phi) - sin(v*(T0 - T3))*cos(T0*u + T3*u + phi) - sin(v*(T1 - T2))*cos(T1*u + T2*u + phi) + sin(v*(T1 - T3))*cos(T1*u + T3*u + phi))/(u**2 - v**2), Ne(u, v)), ((-T0*cos(2*T2*v + phi) + T0*cos(2*T3*v + phi) + T1*cos(2*T2*v + phi) - T1*cos(2*T3*v + phi) + T2*cos(2*T0*v + phi) - T2*cos(2*T1*v + phi) - T3*cos(2*T0*v + phi) + T3*cos(2*T1*v + phi))/(4*v), true))

# %%
#  Rubusty 函数， 积分矩阵的对角， 其中phi=phi1+phi2， 是相位分段函数构造的矩阵
#  实部： 设置 phi=phi即可
#  虚部： 这只 phi = phi + pi/2 即可, 因为  cos(theta+pi/2)=-sin(theta)

A = integrate(cos(u*(t2+t1)+phi)*sin(v*(t2-t1)),(t1,T0,t2))
A = simplify(A)
A = integrate(A,(t2,T0,T1))

simplify(A)
# Out:
# ⎧             -u⋅sin(v⋅(T₀ - T₁))⋅cos(T₀⋅u + T₁⋅u + φ) + v⋅sin(T₀⋅u + φ)⋅cos(T
# ⎪             ────────────────────────────────────────────────────────────────
# ⎪                                                         ⎛ 2    2⎞
# ⎪                                                       u⋅⎝u  - v ⎠
# ⎨
# ⎪T₀⋅v⋅cos(2⋅T₀⋅v + φ) + v⋅(T₀⋅cos(2⋅T₁⋅v + φ) - T₁⋅cos(2⋅T₀⋅v + φ) - T₁⋅cos(2⋅
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                               2
# ⎩                                                            4⋅v
#
# ₀⋅u) - v⋅sin(T₁⋅u + φ)⋅cos(T₁⋅u)
# ────────────────────────────────                for u ≠ v
#
#
#
# T₁⋅v + φ)) - sin(2⋅T₀⋅v + φ) + sin(2⋅T₁⋅v + φ)
# ──────────────────────────────────────────────  otherwise

# %%
print(python(simplify(A)))
# Out:
# u = Symbol('u')
# v = Symbol('v')
# T0 = Symbol('T0')
# T1 = Symbol('T1')
# phi = Symbol('phi')
# e = Piecewise(((-u*sin(v*(T0 - T1))*cos(T0*u + T1*u + phi) + v*sin(T0*u + phi)*cos(T0*u) - v*sin(T1*u + phi)*cos(T1*u))/(u*(u**2 - v**2)), Ne(u, v)), ((T0*v*cos(2*T0*v + phi) + v*(T0*cos(2*T1*v + phi) - T1*cos(2*T0*v + phi) - T1*cos(2*T1*v + phi)) - sin(2*T0*v + phi) + sin(2*T1*v + phi))/(4*v**2), true))

# %%
#  Rubusty 函数image part， 积分矩阵的对角， 其中phi=phi1+phi1=2phi1

A = integrate(sin(u*(t2+t1)+phi)*sin(v*(t2-t1)),(t1,T0,t2))
A = simplify(A)
A = integrate(A,(t2,T0,T1))

simplify(A)
# Out:
# ⎧   3                                          2
# ⎪- u ⋅sin(v⋅(T₀ - T₁))⋅sin(T₀⋅u + T₁⋅u + φ) - u ⋅v⋅sin(T₁⋅u)⋅sin(T₁⋅u + φ) + u
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎨
# ⎪                                                T₀⋅v⋅sin(2⋅T₀⋅v + φ) - v⋅(-T₀
# ⎪                                                ─────────────────────────────
# ⎪
# ⎪
# ⎩
#
# 2             2                                2
#  ⋅v⋅cos(φ) - u ⋅v⋅cos(T₀⋅u)⋅cos(T₀⋅u + φ) + u⋅v ⋅sin(v⋅(T₀ - T₁))⋅sin(T₀⋅u + T
# ──────────────────────────────────────────────────────────────────────────────
#                          ⎛ 4      2  2    4⎞
#                        u⋅⎝u  - 2⋅u ⋅v  + v ⎠
#
# ⋅sin(2⋅T₁⋅v + φ) + T₁⋅sin(2⋅T₀⋅v + φ) + T₁⋅sin(2⋅T₁⋅v + φ)) + cos(2⋅T₀⋅v + φ)
# ──────────────────────────────────────────────────────────────────────────────
#                                   2
#                                4⋅v
#
#
#             3                            3
# ₁⋅u + φ) - v ⋅sin(T₀⋅u)⋅sin(T₀⋅u + φ) + v ⋅sin(T₁⋅u)⋅sin(T₁⋅u + φ)
# ──────────────────────────────────────────────────────────────────  for u ≠ v
#
#
#
# - cos(2⋅T₁⋅v + φ)
# ─────────────────                                                   otherwise

# %%
print(python(simplify(A)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0c8840962fb6> in <module>
# ----> 1 print(python(simplify(A)))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     516     _eval_simplify = getattr(expr, '_eval_simplify', None)
#     517     if _eval_simplify is not None:
# --> 518         return _eval_simplify(ratio=ratio, measure=measure, rational=rational, inverse=inverse)
#     519
#     520     original_expr = expr = signsimp(expr)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in _eval_simplify(self, ratio, measure, rational, inverse)
#     324     def _eval_simplify(self, ratio, measure, rational, inverse):
#     325         args = [a._eval_simplify(ratio, measure, rational, inverse)
# --> 326             for a in self.args]
#     327         _blessed = lambda e: getattr(e.lhs, '_diff_wrt', False) and (
#     328             getattr(e.rhs, '_diff_wrt', None) or
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in <listcomp>(.0)
#     324     def _eval_simplify(self, ratio, measure, rational, inverse):
#     325         args = [a._eval_simplify(ratio, measure, rational, inverse)
# --> 326             for a in self.args]
#     327         _blessed = lambda e: getattr(e.lhs, '_diff_wrt', False) and (
#     328             getattr(e.rhs, '_diff_wrt', None) or
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in _eval_simplify(self, ratio, measure, rational, inverse)
#      63             measure=measure,
#      64             rational=rational,
# ---> 65             inverse=inverse) for a in self.args])
#      66
#      67 class Piecewise(Function):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in <listcomp>(.0)
#      63             measure=measure,
#      64             rational=rational,
# ---> 65             inverse=inverse) for a in self.args])
#      66
#      67 class Piecewise(Function):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/core/expr.py in simplify(self, ratio, measure, rational, inverse)
#    3240         from sympy.core.function import count_ops
#    3241         measure = measure or count_ops
# -> 3242         return simplify(self, ratio, measure)
#    3243
#    3244     def nsimplify(self, constants=[], tolerance=None, full=False):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     580
#     581     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 582         expr = trigsimp(expr, deep=True)
#     583
#     584     if expr.has(log):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in futrig(e, **kwargs)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1082     if args is not None:
#    1083         if args:
# -> 1084             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1085             if args != rv.args:
#    1086                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1082     if args is not None:
#    1083         if args:
# -> 1084             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1085             if args != rv.args:
#    1086                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1085             if args != rv.args:
#    1086                 rv = rv.func(*args)
# -> 1087             rv = F(rv)
#    1088         elif atoms:
#    1089             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in _futrig(e, **kwargs)
#    1167             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1168         )]
# -> 1169     e = greedy(tree, objective=Lops)(e)
#    1170     return coeff*e
#    1171
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in minrule(expr)
#     115     objective = kwargs.get('objective', identity)
#     116     def minrule(expr):
# --> 117         return min([rule(expr) for rule in rules], key=objective)
#     118     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     115     objective = kwargs.get('objective', identity)
#     116     def minrule(expr):
# --> 117         return min([rule(expr) for rule in rules], key=objective)
#     118     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1135         TR1,  # sec-csc -> cos-sin
#    1136         TR12,  # expand tan of sum
# -> 1137         lambda x: _eapply(factor, x, trigs),
#    1138         TR2,  # tan-cot -> sin-cos
#    1139         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in _eapply(func, e, cond)
#    1188         return e
#    1189     if _is_Expr(e) or not e.args:
# -> 1190         return func(e)
#    1191     return e.func(*[
#    1192         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in factor(f, *gens, **args)
#    6347
#    6348     try:
# -> 6349         return _generic_factor(f, gens, args, method='factor')
#    6350     except PolynomialError as msg:
#    6351         if not f.is_commutative:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in _generic_factor(expr, gens, args, method)
#    6019     opt = options.build_options(gens, args)
#    6020     opt['fraction'] = fraction
# -> 6021     return _symbolic_factor(sympify(expr), opt, method)
#    6022
#    6023
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor(expr, opt, method)
#    5962         if hasattr(expr,'_eval_factor'):
#    5963             return expr._eval_factor()
# -> 5964         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    5965         return _keep_coeff(coeff, _factors_product(factors))
#    5966     elif hasattr(expr, 'args'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor_list(expr, opt, method)
#    5930             func = getattr(poly, method + '_list')
#    5931
# -> 5932             _coeff, _factors = func()
#    5933             if _coeff is not S.One:
#    5934                 if exp.is_Integer:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polytools.py in factor_list(f)
#    3238         if hasattr(f.rep, 'factor_list'):
#    3239             try:
# -> 3240                 coeff, factors = f.rep.factor_list()
#    3241             except DomainError:
#    3242                 return S.One, [(f, 1)]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/polyclasses.py in factor_list(f)
#     794     def factor_list(f):
#     795         """Returns a list of irreducible factors of ``f``. """
# --> 796         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     797         return coeff, [ (f.per(g), k) for g, k in factors ]
#     798
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_factor_list(f, u, K0)
#    1281         if K.is_ZZ:
#    1282             levels, f, v = dmp_exclude(f, u, K)
# -> 1283             coeff, factors = dmp_zz_factor(f, v, K)
#    1284
#    1285             for i, (f, k) in enumerate(factors):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_zz_factor(f, u, K)
#    1092     if dmp_degree(g, u) > 0:
#    1093         g = dmp_sqf_part(g, u, K)
# -> 1094         H = dmp_zz_wang(g, u, K)
#    1095         factors = dmp_trial_division(f, H, u, K)
#    1096
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_zz_wang(f, u, K, mod, seed)
#    1015     try:
#    1016         f, H, LC = dmp_zz_wang_lead_coeffs(f, T, cs, E, H, A, u, K)
# -> 1017         factors = dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#    1018     except ExtraneousFactors:  # pragma: no cover
#    1019         if query('EEZ_RESTART_IF_NEEDED'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#     879             if not dmp_zero_p(C, w - 1):
#     880                 C = dmp_quo_ground(C, K.factorial(k + 1), w - 1, K)
# --> 881                 T = dmp_zz_diophantine(G, C, I, d, p, w - 1, K)
#     882
#     883                 for i, (h, t) in enumerate(zip(H, T)):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     791     else:
#     792         n = len(A)
# --> 793         e = dmp_expand(F, u, K)
#     794
#     795         a, A = A[-1], A[:-1]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_expand(polys, u, K)
#    1828
#    1829     for g in polys[1:]:
# -> 1830         f = dmp_mul(f, g, u, K)
#    1831
#    1832     return f
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     828
#     829         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 830             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     831
#     832         h.append(coeff)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     828
#     829         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 830             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     831
#     832         h.append(coeff)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     828
#     829         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 830             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     831
#     832         h.append(coeff)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     828
#     829         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 830             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     831
#     832         h.append(coeff)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_mul(f, g, u, K)
#     828
#     829         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 830             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     831
#     832         h.append(coeff)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     578
#     579     if df == dg:
# --> 580         return dmp_strip([ dmp_add(a, b, v, K) for a, b in zip(f, g) ], u)
#     581     else:
#     582         k = abs(df - dg)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dmp_add(f, g, u, K)
#     563     """
#     564     if not u:
# --> 565         return dup_add(f, g, K)
#     566
#     567     df = dmp_degree(f, u)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/polys/densearith.py in dup_add(f, g, K)
#     536
#     537     if df == dg:
# --> 538         return dup_strip([ a + b for a, b in zip(f, g) ])
#     539     else:
#     540         k = abs(df - dg)
#
# KeyboardInterrupt:

# %%
A = trigsimp(A)
A
# Out:
# ⎧    ⎛                             2                            2       ⎞
# ⎪    ⎜                            v ⋅sin(T₀⋅u)⋅sin(T₀⋅u + φ)   v ⋅cos(φ)⎟
# ⎪  v⋅⎜u⋅cos(T₀⋅u)⋅cos(T₀⋅u + φ) + ────────────────────────── - ─────────⎟   -s
# ⎪    ⎝                                        u                    u    ⎠
# ⎪- ────────────────────────────────────────────────────────────────────── + ──
# ⎪                                         2
# ⎪                                ⎛ 2    2⎞
# ⎨                                ⎝u  - v ⎠
# ⎪
# ⎪
# ⎪                 T₀⋅sin(2⋅T₀⋅v + φ) + T₀⋅sin(2⋅T₁⋅v + φ) - T₁⋅sin(2⋅T₀⋅v + φ)
# ⎪
# ⎪                 ────────────────────────────────────────────────────────────
# ⎪                                                                          4⋅v
# ⎩
#
#
#                                        v⋅sin(T₁⋅u)⋅sin(T₁⋅u + φ)   v⋅cos(φ)
# in(v⋅(T₀ - T₁))⋅sin(T₀⋅u + T₁⋅u + φ) - ───────────────────────── + ────────
#                                                    u                  u
# ───────────────────────────────────────────────────────────────────────────  f
#                                   2    2
#                                  u  - v
#
#
#                         cos(2⋅T₀⋅v + φ)   cos(2⋅T₁⋅v + φ)
#  - T₁⋅sin(2⋅T₁⋅v + φ) + ─────────────── - ───────────────
#                                v                 v
# ─────────────────────────────────────────────────────────                    o
#
#
#
#
#
#
#
# or u ≠ v
#
#
#
#
#
#
#
# therwise

# %%
print(python(A))
# Out:
# v = Symbol('v')
# u = Symbol('u')
# T0 = Symbol('T0')
# phi = Symbol('phi')
# T1 = Symbol('T1')
# e = Piecewise((-v*(u*cos(T0*u)*cos(T0*u + phi) + v**2*sin(T0*u)*sin(T0*u + phi)/u - v**2*cos(phi)/u)/(u**2 - v**2)**2 + (-sin(v*(T0 - T1))*sin(T0*u + T1*u + phi) - v*sin(T1*u)*sin(T1*u + phi)/u + v*cos(phi)/u)/(u**2 - v**2), Ne(u, v)), ((T0*sin(2*T0*v + phi) + T0*sin(2*T1*v + phi) - T1*sin(2*T0*v + phi) - T1*sin(2*T1*v + phi) + cos(2*T0*v + phi)/v - cos(2*T1*v + phi)/v)/(4*v), true))

# %%
## 计算 alpha 

A = integrate(sin(u*t+phi)*exp(I*v*t),(t,T0,T1))

A=simplify(A)

# %%
A=simplify(A)
print(python(A))
# Out:
# u = Symbol('u')
# T0 = Symbol('T0')
# v = Symbol('v')
# phi = Symbol('phi')
# T1 = Symbol('T1')
# e = Piecewise(((u*exp(I*T0*v)*cos(T0*u + phi) - u*exp(I*T1*v)*cos(T1*u + phi) - I*v*exp(I*T0*v)*sin(T0*u + phi) + I*v*exp(I*T1*v)*sin(T1*u + phi))/(u**2 - v**2), Ne(u, v)), ((-v*(T0*exp(I*T0*v)*sin(T0*v + phi) + I*T0*exp(I*T0*v)*cos(T0*v + phi) - T1*exp(I*T1*v)*sin(T1*v + phi) - I*T1*exp(I*T1*v)*cos(T1*v + phi)) + exp(I*T0*v)*cos(T0*v + phi) - exp(I*T1*v)*cos(T1*v + phi))/(2*v), true))

# %% [markdown]
# 其他函数积分

# %%
A = integrate(sin(u*t1)*sin(u*t2)*sin(v*(t2-t1)),(t1,0,t2))
A = simplify(A)
B = integrate(A,(t2,0,T1))

simplify(simplify(B))
# Out:
# ⎧        3             3      3                      3                    2
# ⎪- 2⋅T₁⋅u ⋅v + 2⋅T₁⋅u⋅v  + 2⋅u ⋅sin(T₁⋅(u - v)) - 2⋅u ⋅sin(T₁⋅(u + v)) + u ⋅v⋅
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪                                                                           ⎛
# ⎨                                                                       4⋅u⋅⎝u
# ⎪
# ⎪                                                         2⋅T₁⋅v⋅(cos(2⋅T₁⋅v)
# ⎪                                                         ────────────────────
# ⎪
# ⎩                                                                          16⋅
#
#                  2                        2                      3
# sin(2⋅T₁⋅u) + 2⋅u ⋅v⋅sin(T₁⋅(u - v)) + 2⋅u ⋅v⋅sin(T₁⋅(u + v)) - v ⋅sin(2⋅T₁⋅u)
# ──────────────────────────────────────────────────────────────────────────────
#        2
# 2    2⎞
#   - v ⎠
#
# + 2) - 3⋅sin(2⋅T₁⋅v)
# ────────────────────
#  2
# v
#
#
#
#   for u ≠ v
#
#
#
#
#
#   otherwise

# %%
A = integrate(sin(u*t1)*exp(I*v*t1),(t1,0,t))
A
# Out:
# ⎧         ⅈ⋅τ⋅v                           ⅈ⋅τ⋅v
# ⎪      u⋅ℯ     ⋅cos(τ⋅u)      u      ⅈ⋅v⋅ℯ     ⋅sin(τ⋅u)
# ⎪    - ───────────────── + ─────── + ───────────────────      for u ≠ v
# ⎪            2    2         2    2          2    2
# ⎪           u  - v         u  - v          u  - v
# ⎨
# ⎪   ⅈ⋅τ⋅v                 ⅈ⋅τ⋅v               ⅈ⋅τ⋅v
# ⎪τ⋅ℯ     ⋅sin(τ⋅v)   ⅈ⋅τ⋅ℯ     ⋅cos(τ⋅v)   ⅈ⋅ℯ     ⋅sin(τ⋅v)
# ⎪───────────────── + ─────────────────── - ─────────────────  otherwise
# ⎪        2                    2                   2⋅v
# ⎩

# %%
A = integrate(sin(v*(t2-t1)),(t1,T0,T1))
integrate(A,(t2,T2,T3))
# Out:
# sin(v⋅(-T₀ + T₂))   sin(v⋅(-T₀ + T₃))   sin(v⋅(-T₁ + T₂))   sin(v⋅(-T₁ + T₃))
# ───────────────── - ───────────────── - ───────────────── + ─────────────────
#          2                   2                   2                   2
#         v                   v                   v                   v

# %% [markdown]
# # 优化类整合

# %% [markdown]
# ## 定义类

# %%
class IonChain:
    positions0=None # ion ballance postions on the chain, has been normed with lattice_d
    lattice_d = None # lattice distance, um
    N = None  # ion number of the chain
    DipoleList = None  # DipoleList on the chain
    b=None      # ratial / axis paramter
    Omega_SDF=None
    C_eta = 462.391277099127  # eta = C_eta/sqrt(omega), get from 171Yb Raman excitaion @ 369nm, 
    
    def __init__(self,N,beta,v0,DipoleList=None):
        self.lattice_d=1.0
        self.N=N
        self.beta=beta
        self.v0 = v0  # v0 is the basic frequency
        self.DipoleList=DipoleList
        
        self.mode_x()
        self.mode_z()
        
    def get_ion_pos(self):
        def position(x):
            # list 长度为离子数目, x list 是每个离子的位置初值，通过迭代法求解 x0 。
            n = len(x)
            e = np.zeros(n) #n个平衡方程
            for i in range(1,n-1):
                for j in range(0,i):
                    e[i] = e[i] - 1/(x[i]-x[j])**2
                for k in range(i+1,n):
                    e[i] = e[i] + 1/(x[i]-x[k])**2
                e[i] = e[i] + x[i]
            for i in range(1,n):
                e[0] = e[0] + 1/(x[0]-x[i])**2
            e[0] = e[0] + x[0]
            for i in range(0,n-1):
                e[n-1] = e[n-1] - 1/(x[n-1]-x[i])**2
            e[n-1] = e[n-1] + x[n-1]
            return(np.array(e))

        x0 = np.arange(self.N)  # 数值运算的初始值。 list 长度为离子数目
        result = fsolve(position, x0)
        self.positions0 = result
        return result

    # 求解径向频率分布的改变, 注意 sqrt(f2) 是频率分布
    def mode_x(self):
        #  n 为离子数
        #  b为trap参数， w_x/w_z的数值
        # DipoleList，形式为[(i,b_i),(j,b_j),....] 分别在 i个离子上施加b_i 的局域势...
        # DipoleList 为None时， 为普通阱
        n = self.N
        A = np.zeros((n,n)) #展开矩阵
        u = self.get_ion_pos()
        for i in range(0,n):
            A[i][i] =  self.beta**2
            for j in range(0,n):
                if i != j:
                    A[i][j]  =  1/abs(u[i]-u[j])**3
                    A[i][i] += -1/abs(u[i]-u[j])**3
        if self.DipoleList is not None:
            for k, b1 in DipoleList:
                A[k][k] = A[k][k] + b1**2
        a,b = np.linalg.eig(A)
        self.a_x,self.V_x = self.arangeEig(a,b)
        self.vs_x = np.sqrt(self.a_x)*self.v0
        self.eta_x = self.C_eta/np.sqrt(self.vs_x)
        self.g_x = self.eta_x * self.V_x 
        
        return self.a_x,self.V_x 

    # 求轴向的频率分布
    def mode_z(self):
        #  n 为离子数
        #  b为trap参数， w_x/w_z的数值
        # DipoleList，形式为[(i,b_i),(j,b_j),....] 分别在 i个离子上施加b_i 的局域势...
        # DipoleList 为None时， 为普通阱
        n = self.N
        A = np.zeros((n,n)) #展开矩阵
        u = self.get_ion_pos()
        for i in range(0,n):
            A[i][i] = 1      # 对角项初始值， 便于后续积分
            for j in range(0,n):
                if i != j:
                    A[i][j]  =   -2/abs(u[i]-u[j])**3  # 非对角项
                    A[i][i] +=  2/abs(u[i]-u[j])**3  # 对角项需要积分， p=j

        if DipoleList is not None:
            for k, b1 in DipoleList:
                A[k][k] = A[k][k] + b1**2
        #注意 sqrt(a) 是频率分布
        a,b = np.linalg.eig(A)
        self.a_z,self.V_z = self.arangeEig(a,b)
        self.vs_z = np.sqrt(self.a_z)*self.v0
        self.eta_z = self.C_eta/np.sqrt(self.vs_z)
        self.g_z =  self.eta_z * self.V_z
        return self.a_z,self.V_z
    
    def resortEig(self, M, indexM):
        # resort matrix eigs with index matrix or index vectors indexM[:,i]
        m,n = M.shape
        index = []
        for i in range(n):
            p = [np.abs(np.dot(M[:,j],indexM[:,i]))/np.linalg.norm(M[:,j])/np.linalg.norm(indexM[:,i]) for j in range(n)]
            index.append(np.argmax(p))
        return np.array(index)


    def arangeEig(self,a,V):
        index = np.argsort(a)
        return (a[index], V[:,index])




from sympy import *
from scipy.integrate  import simps, cumtrapz

T0,T1,T2,T3,v,t1,t2, u,t,phi = symbols('T0,T1,T2,T3,v,t1,t2,u,tau,phi',real=True,positive=True)

# 非对角项的表达式
e0_phase = Piecewise(((-u**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + u**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + u**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - u**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi) - 2*u*v*sin(-T0*u + T2*u + phi)*cos(v*(T0 - T2)) + 2*u*v*sin(-T0*u + T3*u + phi)*cos(v*(T0 - T3)) + 2*u*v*sin(-T1*u + T2*u + phi)*cos(v*(T1 - T2)) - 2*u*v*sin(-T1*u + T3*u + phi)*cos(v*(T1 - T3)) - v**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + v**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + v**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - v**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi))/(u**2 - v**2)**2, Ne(u, v)), ((-4*T2*v**2*(T0 - T1)*sin(phi) + 4*T3*v**2*(T0 - T1)*sin(phi) + sin(-2*T0*v + 2*T2*v + phi) - sin(-2*T0*v + 2*T3*v + phi) - sin(-2*T1*v + 2*T2*v + phi) + sin(-2*T1*v + 2*T3*v + phi))/(8*v**2), true))
e0_robust = Piecewise(((sin(v*(T0 - T2))*cos(T0*u + T2*u + phi) - sin(v*(T0 - T3))*cos(T0*u + T3*u + phi) - sin(v*(T1 - T2))*cos(T1*u + T2*u + phi) + sin(v*(T1 - T3))*cos(T1*u + T3*u + phi))/(u**2 - v**2), Ne(u, v)), ((-T0*cos(2*T2*v + phi) + T0*cos(2*T3*v + phi) + T1*cos(2*T2*v + phi) - T1*cos(2*T3*v + phi) + T2*cos(2*T0*v + phi) - T2*cos(2*T1*v + phi) - T3*cos(2*T0*v + phi) + T3*cos(2*T1*v + phi))/(4*v), true))    


# 对角项的表达式
#e1_phase = Piecewise(((T0*u**2*v*cos(phi) - T0*v**3*cos(phi) - T1*u**2*v*cos(phi) + T1*v**3*cos(phi) + u**2*sin(v*(T0 - T1))*cos(-T0*u + T1*u + phi) - 2*u*v*sin(phi) + 2*u*v*sin(-T0*u + T1*u + phi)*cos(v*(T0 - T1)) + v**2*sin(v*(T0 - T1))*cos(-T0*u + T1*u + phi))/(u**2 - v**2)**2, Ne(u, v)), ((-2*T0*v*(T0*v*sin(phi) + cos(phi)) + 2*T1*v*(2*T0*v*sin(phi) - T1*v*sin(phi) + cos(phi)) + sin(phi) - sin(-2*T0*v + 2*T1*v + phi))/(8*v**2), true))
e1_phase = Piecewise(((T0*u**2*v - T0*v**3 - T1*u**2*v + T1*v**3 + u**2*sin(v*(T0 - T1))*cos(u*(T0 - T1)) - 2*u*v*sin(u*(T0 - T1))*cos(v*(T0 - T1)) + v**2*sin(v*(T0 - T1))*cos(u*(T0 - T1)))/(u**2 - v**2)**2, Ne(u, v)), ((-2*T0*v + 2*T1*v + sin(2*v*(T0 - T1)))/(8*v**2), true))
e1_robust = Piecewise(((-u*sin(v*(T0 - T1))*cos(T0*u + T1*u + phi) + v*sin(T0*u + phi)*cos(T0*u) - v*sin(T1*u + phi)*cos(T1*u))/(u*(u**2 - v**2)), Ne(u, v)), ((T0*v*cos(2*T0*v + phi) + v*(T0*cos(2*T1*v + phi) - T1*cos(2*T0*v + phi) - T1*cos(2*T1*v + phi)) - sin(2*T0*v + phi) + sin(2*T1*v + phi))/(4*v**2), true))

# alpha_f 表达式
e_alpha_f = Piecewise(((u*exp(I*T0*v)*cos(T0*u + phi) - u*exp(I*T1*v)*cos(T1*u + phi) - I*v*exp(I*T0*v)*sin(T0*u + phi) + I*v*exp(I*T1*v)*sin(T1*u + phi))/(u**2 - v**2), Ne(u, v)), ((-v*(T0*exp(I*T0*v)*sin(T0*v + phi) + I*T0*exp(I*T0*v)*cos(T0*v + phi) - T1*exp(I*T1*v)*sin(T1*v + phi) - I*T1*exp(I*T1*v)*cos(T1*v + phi)) + I*exp(I*T0*v)*sin(T0*v + phi) - I*exp(I*T1*v)*sin(T1*v + phi))/(2*v), true))

f0_phase = lambdify((T0,T1,T2,T3,u,v,phi), e0_phase, 'numpy' )
f0_robust = lambdify((T0,T1,T2,T3,u,v,phi), e0_robust, 'numpy' )

f1_phase = lambdify((T0,T1,u,v), e1_phase, 'numpy' )
f1_robust = lambdify((T0,T1,u,v,phi), e1_robust, 'numpy' )

f_alpha_f = lambdify((T0,T1,u,v,phi), e_alpha_f, 'numpy' )


class Ion_Gate:
    N=None        #   N segments
    Ts = None     # Intervals list
    ts = None     # time list for intervals
    Amps = None   # amplitude list
    Phases = None   # phase list
    Ion_Chain_Setting = None
    def __init__(self,Ion_Chain_Setting,N=None):
        self.Ion_Chain_Setting = Ion_Chain_Setting
        self.N = N
        
    def setSegments(self,Ts,Amps,Phases):
        if len(Ts)!=len(Amps):
            raise ValueError('lens of Ts and Amps not equal')
        self.N = len(Ts)
        self.Ts = np.array(Ts)
        self.Amps = np.array(Amps)
        self.Phases = np.array(Phases)
        self.ts =  np.cumsum(np.concatenate(([0],Ts)))
        
    def setSemiSegments(self,Tss,Ampss,Phasess):  # set harf of the Amps list, and let waveform symmetri 
        Ts = np.concatenate((Tss,Tss[::-1][0:]))
        Amps = np.concatenate((Ampss,Ampss[::-1][0:]))
        Phases = np.concatenate((Phasess,-Phasess[::-1][0:]))
        self.setSegments(Ts,Amps,Phases)


    def Geometry_Phase(self,u, vm):  # Geometry_phase part, the exact may need time some coffiecient
        t = self.ts
        t_i1,t_k = np.meshgrid(t[:-1],t[1:])
        t_i,t_k1 = np.meshgrid(t[1:],t[:-1])
        
        A_i,A_k = np.meshgrid(self.Amps,self.Amps)
        
        Phi_i,Phi_k = np.meshgrid(self.Phases,self.Phases)
        Phi = Phi_k-Phi_i  # need to check A-B or B-A
        
        M_phase = f0_phase(t_i1,t_i,t_k1,t_k,u,vm,Phi)
        phase_diag =  f1_phase(t[:-1],t[1:],u,vm)
        np.fill_diagonal(M_phase, phase_diag)
        
        M = A_k*A_i*M_phase
        G_phase = np.sum(np.tril(M))
        return G_phase
    
    def Geometry_Phase_time(self, u, vm):  # Geometry_phase part, the exact may need time some coffiecient
        t = self.ts
        T = self.Ts
        G = []
        for i,TT in enumerate(T):
            t_list = np.linspace(0,TT,100)
            for j,ttt in enumerate(t_list):
                T_list = np.append(t[0:i+1],[ttt+t[i]])
                t_i1,t_k = np.meshgrid(T_list[:-1],T_list[1:])
                t_i,t_k1 = np.meshgrid(T_list[1:],T_list[:-1])

                A_i,A_k = np.meshgrid(self.Amps[0:i+1],self.Amps[0:i+1])

                Phi_i,Phi_k = np.meshgrid(self.Phases[0:i+1],self.Phases[0:i+1])
                Phi = Phi_k-Phi_i  # need to check A-B or B-A
                
                M_phase = f0_phase(t_i1,t_i,t_k1,t_k,u,vm,Phi)
                phase_diag =  f1_phase(T_list[:-1],T_list[1:],u,vm)
                np.fill_diagonal(M_phase, phase_diag)

                M = A_k*A_i*M_phase
                G_phase = np.sum(np.tril(M))
                G.append(G_phase)

        return G

    def Robusty(self,u,vm):  # Raman u laser detune, vm: phonon freqency
        t = self.ts
        t_i1,t_k = np.meshgrid(t[:-1],t[1:])
        t_i,t_k1 = np.meshgrid(t[1:],t[:-1])

        A_i,A_k = np.meshgrid(self.Amps,self.Amps)
        
        Phi_i,Phi_k = np.meshgrid(self.Phases,self.Phases)
        Phi = Phi_k+Phi_i  # note, phi1+phi2

        M_real = f0_robust(t_i1,t_i,t_k1,t_k,u,vm,Phi)
        real_diag = f1_robust(t[:-1],t[1:],u,vm,2*self.Phases)
        np.fill_diagonal(M_real, real_diag)

        M_imag = f0_robust(t_i1,t_i,t_k1,t_k,u,vm,Phi+np.pi/2)
        imag_diag = f1_robust(t[:-1],t[1:],u,vm,2*self.Phases++np.pi/2) # phi+phi=2*phi
        np.fill_diagonal(M_imag, imag_diag)

        imag = np.sum(np.tril(A_k*A_i*M_real))
        real = np.sum(np.tril(A_k*A_i*M_imag))

        return np.sqrt(imag**2+real**2)


    def Alpha_f(self,u,v,phi=0):
        t = self.ts
        return np.sum(self.Amps*f_alpha_f(t[:-1],t[1:],u,v,self.Phases+phi))


    def f_modulation(self,N=1000):   # modulation function
    # return time , Amplitude line, phase line
        t = self.ts
        g = self.Amps
        tl = np.linspace(0,t[-1],N+1)
        gl = np.zeros(len(tl))
        pl = np.zeros(len(tl))

        for i, ti0,ti in zip(range(len(t)-1),t[:-1],t[1:]):
            index =np.logical_and(ti0<=tl,tl<=ti)
            gl[index]=g[i]
            pl[index]=self.Phases[i]
        return tl,gl, pl

    def f_alpha_x(self,u,ion_i,ion_j,mode_index,phi0=0,N=10000):
        t = self.ts
        g = self.Amps
        tl,fg,phase = self.f_modulation(N)
        dt = tl[1]-tl[0]
        v = self.Ion_Chain_Setting.vs_x[mode_index]
        g_x = self.Ion_Chain_Setting.g_x
        omega =  (np.abs(g_x[ion_i,mode_index])+np.abs(g_x[ion_i,mode_index]))
        # can not determin the spin of  ion_i and ion_j, so we use the abs() + abs()

        kernal = 1.0j*omega*fg*np.sin(u*tl+phi0+phase)*np.exp(1.0j*v*tl)
        trace = cumtrapz(kernal,dx=dt)
        trace = np.concatenate(([0],trace))
        pieces = []
        for ti0,ti in zip(t[:-1],t[1:]):
            a = int(ti0/dt)
            b = int(ti/dt)
            pieces.append(trace[a:b])
        return pieces
    
    def optimize_value(self,u,i,j):  # g is the modulation amplitude, on i, j th ion
        
        dR_list=[]
        dalpha_list=[]
        G_phase_list=[]
        G_phase_time_list=[]
        
#         Omega_SDF = self.Ion_Chain_Setting.Omega_SDF
        Omega_SDF = 1
        g_i,g_j = self.Ion_Chain_Setting.g_x[i],self.Ion_Chain_Setting.g_x[j]
        for m,vm in enumerate(self.Ion_Chain_Setting.vs_x):
            g_mi,g_mj = g_i[m], g_j[m]
            R = g_mi*g_mj*Omega_SDF**2*self.Robusty(u,vm)
            dalpha1 = (np.abs(g_mi)+np.abs(g_mj))*Omega_SDF*np.abs(self.Alpha_f(u,vm))
            dalpha2 = (np.abs(g_mi)+np.abs(g_mj))*Omega_SDF*np.abs(self.Alpha_f(u,vm,np.pi/2))
            Gphase  = g_mi*g_mj*Omega_SDF**2*self.Geometry_Phase(u,vm)
            Gphase_time = g_mi*g_mj*Omega_SDF**2*np.array(self.Geometry_Phase_time(u,vm))

            G_phase_list.append(Gphase)
            G_phase_time_list.append(Gphase_time)
            dR_list.append(R**2)                       # note
            dalpha_list.append(dalpha1**2+dalpha2**2)  # note
            
        Omega_SDF = np.sqrt(np.abs(np.pi/(4*np.sum(G_phase_list))))
        self.dR2 = np.array(dR_list)*Omega_SDF**4
        self.dalpha2 = np.array(dalpha_list)*Omega_SDF**2
        self.G_phase = np.array(G_phase_list)*Omega_SDF**2
        G = np.array(G_phase_time_list)*Omega_SDF**2
        S1 = np.sum(np.array(dR_list))*Omega_SDF**4
        S2 = np.sum(np.array(dalpha_list))*Omega_SDF**2
        print(S1,S2,Omega_SDF/(2*np.pi*1e6))
        return S1+S2, Omega_SDF/(2*np.pi*1e6), G
#         phase_error = np.abs(np.abs(np.sum(G_phase_list))-np.pi/4)
#         print(S1,S2,phase_error,np.abs(np.sum(G_phase_list)))
#         return S1+S2+phase_error     # proportional to fidelity


def plot_traces_main(traces):
    m = []
    for trace in traces:
        x,y = np.real(trace),np.imag(trace)
        m.append(np.max(x))
        m.append(np.max(y))
        plt.plot(x,y,lw=2)
    plt.plot(np.real(traces[0][0]),np.imag(traces[0][0]),'o',markersize=10,c='r')
    plt.plot(np.real(traces[-1][-1]),np.imag(traces[-1][-1]),'*',markersize=10,c='b')
    return np.max(m) 

    
def plot_traces_other(traces):
    m = []
    for trace in traces:
        x,y = np.real(trace),np.imag(trace)
        m.append(np.max(x))
        m.append(np.max(y))
#         plt.plot(x,y)
    plt.plot(np.real(traces[0][0]),np.imag(traces[0][0]),'o',markersize=10,c='r')
    plt.plot(np.real(traces[-1][-1]),np.imag(traces[-1][-1]),'*',markersize=10,c='b')
    return np.max(m)

# %%
N_ions = 10
dipole_strenth = 19.6424957
ion_i = 5
ion_j = 4
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
# IonChainSetting.Omega_SDF =  5e6 *2 *np.pi # SDF induced Rabi


ion_amps = Ion_Gate(IonChainSetting)

# u0= np.average(IonChainSetting.vs_x[-2:])+ delta
# T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 
u0 = 2*np.pi*2.4e6
T0 = np.array([0.6216952,2.5-0.6216952])*1e-6
phases0 = np.array([1.63130249,1.61250117])
A0 = np.array([1,1])

N_Semi = len(T0)   # total segments is 2*N_semi-1

ion_amps.setSemiSegments(T0,A0,phases0)
Omega_SDF = ion_amps.optimize_value(u0,ion_i,ion_j)[1]*2*np.pi*1e6
g = ion_amps.optimize_value(u0,ion_i,ion_j)[2]
G = np.zeros(400)
for i in range(400):
    for j in range(10):
        G[i] = g[j][i] + G[i]
# plt.plot(*ion_amps.f_modulation())
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plot_traces_main(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-2))*Omega_SDF)
plt.text(-1.5, -1.5, '$ \\alpha_j^k$', fontsize=20)
plt.vlines(0,-2.5,2.5,linewidth=0.5)
plt.hlines(0,-2.5,2.5,linewidth=0.5)
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,2)
plot_traces_main(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))*Omega_SDF)
plt.vlines(0,-2.5,2.5,linewidth=0.5)
plt.hlines(0,-2.5,2.5,linewidth=0.5)
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,3)
for i in range(10):
    plot_traces_other(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,i))*Omega_SDF)
    plt.ticklabel_format(axis='y',style='sci',scilimits=(0,3)) 
    plt.ticklabel_format(axis='x',style='sci',scilimits=(0,3))  
plt.xlim(-0.0016,0.0016)
plt.ylim(-0.0016,0.0016)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,4)
T1 = np.linspace(0,0.6216952,100)
T2 = np.linspace(0.6216952,2.5,100)
T3 = np.linspace(2.5,5-0.6216952,100)
T4 = np.linspace(5-0.6216952,5,100)
plt.plot(T1,G[0:100],lw=3)
plt.plot(T2,G[100:200],lw=3)
plt.plot(T3,-np.pi/4-G[199:99:-1],lw=3)
plt.plot(T4,-np.pi/4-G[99::-1],lw=3)
my_y_ticks = [0,-np.pi/4]
plt.yticks(my_y_ticks,('$0$','$-\pi/4$'))
plt.plot(T1[0],G[0],'o',markersize=6,c='r')
plt.plot(T4[-1],G[-1],'*',markersize=10,c='b')
plt.xlabel(r'$\mu s$')
plt.ylabel(r'$\Phi_{2,m}$')
plt.savefig('../fig/phase_space.pdf')
# Out:
# 0.003479336631820929 0.0014397495408648932 4.327716183292014
# 0.003479336631820929 0.0014397495408648932 4.327716183292014

# %%
import pandas as pd

#任意的多组列表
a = np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))*Omega_SDF
b = np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-2))*Omega_SDF
c = np.zeros(10)
d = [0,0.6216952,2.5,5-0.6216952,5]
for i in range(10):
    c[i] = np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,i)[-1][-1])*Omega_SDF
df1 = pd.DataFrame({'mode_1_1':a[0]})
df2 = pd.DataFrame({'mode_1_2':a[1]})
df3 = pd.DataFrame({'mode_1_3':a[2]})
df4 = pd.DataFrame({'mode_1_4':a[3]})
df5 = pd.DataFrame({'mode_2_1':b[0]})
df6 = pd.DataFrame({'mode_2_2':b[1]})
df7 = pd.DataFrame({'mode_2_3':b[2]})
df8 = pd.DataFrame({'mode_2_4':b[3]})
df9 = pd.DataFrame({'other_mode':c})
df10 = pd.DataFrame({'g_phase':G})
df11 = pd.DataFrame({'time':d})
# df12 = pd.DataFrame({'t2':T2})
# df13 = pd.DataFrame({'t3':T3})
# df14 = pd.DataFrame({'t4':T4})
#字典中的key值即为csv中列名
dataframe = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)
#                           pd.DataFrame({'mode_2_1':b[0]}),pd.DataFrame({'mode_2_2':b[1]}),pd.DataFrame({'mode_2_3':b[2]}),pd.DataFrame({'mode_2_4':b[3]}), \
#                           pd.DataFrame({'other_mode':c}),pd.DataFrame({'g_phase':G}),\
#                        pd.DataFrame({'time':d})])

#将DataFrame存储为csv,index表示是否显示行名，default=True
dataframe.to_csv("trace.csv",index=True)
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: ComplexWarning: Casting complex values to real discards the imaginary part
#   if __name__ == '__main__':

# %%
print(np.real(a[0]))
# Out:
# [ 0.00000000e+00 -7.87818014e-06 -3.15038627e-05 ...  9.35317892e-01
#   9.37818896e-01  9.40320357e-01]

# %%
np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))*Omega_SDF
# Out:
# array([array([ 0.00000000e+00+0.j        , -7.87818014e-06+0.00249666j,
#        -3.15038627e-05+0.00499194j, ...,  9.35317892e-01+0.86183765j,
#         9.37818896e-01+0.86177925j,  9.40320357e-01+0.86173664j]),
#        array([0.94282203+0.86170982j, 0.94532382+0.86169879j,
#        0.94782566+0.86170355j, ..., 0.02418062-0.16436152j,
#        0.02385463-0.16188167j, 0.02351306-0.15940443j]),
#        array([ 0.02352081-0.15940294j,  0.02389354-0.16187504j,
#         0.02428196-0.16434538j, ..., -1.16073953+0.54738486j,
#        -1.15833433+0.54807245j, -1.15593332+0.54877527j]),
#        array([-1.15353672e+00+5.49493249e-01j, -1.15114472e+00+5.50226338e-01j,
#        -1.14875739e+00+5.50974514e-01j, ...,
#        -1.72618635e-03+4.71460201e-03j, -1.04368275e-03+2.31584013e-03j,
#        -3.45652457e-04-7.99333374e-05j])], dtype=object)

# %%
N_ions = 10
dipole_strenth = 19.6424957
ion_i = 5
ion_j = 4
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
# IonChainSetting.Omega_SDF =  5e6 *2 *np.pi # SDF induced Rabi


ion_amps = Ion_Gate(IonChainSetting)

# u0= np.average(IonChainSetting.vs_x[-2:])+ delta
# T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 
u0 = 2*np.pi*2.4e6
T0 = np.array([0.6216952,2.5-0.6216952])*1e-6/5
phases0 = np.array([1.63130249,1.61250117])
A0 = np.array([1,1])

N_Semi = len(T0)   # total segments is 2*N_semi-1

ion_amps.setSemiSegments(T0,A0,phases0)
Omega_SDF = ion_amps.optimize_value(u0,ion_i,ion_j)[1]*2*np.pi*1e6
g = ion_amps.optimize_value(u0,ion_i,ion_j)[1]
G = np.zeros(400)
for i in range(400):
    for j in range(10):
        G[i] = g[j][i] + G[i]
# plt.plot(*ion_amps.f_modulation())
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plot_traces_main(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-2))*Omega_SDF)
plt.text(-1.5, -1.5, '$ \\alpha_j^k$', fontsize=20)
plt.vlines(0,-2.5,2.5,linewidth=0.5)
plt.hlines(0,-2.5,2.5,linewidth=0.5)
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,2)
plot_traces_main(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))*Omega_SDF)
plt.vlines(0,-2.5,2.5,linewidth=0.5)
plt.hlines(0,-2.5,2.5,linewidth=0.5)
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,3)
for i in range(10):
    plot_traces_other(np.array(ion_amps.f_alpha_x(u0,ion_i,ion_j,i))*Omega_SDF)
    plt.ticklabel_format(axis='y',style='sci',scilimits=(0,3)) 
    plt.ticklabel_format(axis='x',style='sci',scilimits=(0,3))  
plt.xlim(-0.0016,0.0016)
plt.ylim(-0.0016,0.0016)
plt.xlabel(r'Re($\alpha$)')
plt.ylabel(r'Im($\alpha$)')
plt.subplot(2,2,4)
T1 = np.linspace(0,0.6216952,100)
T2 = np.linspace(0.6216952,2.5,100)
T3 = np.linspace(2.5,5-0.6216952,100)
T4 = np.linspace(5-0.6216952,5,100)
plt.plot(T1,G[0:100],lw=3)
plt.plot(T2,G[100:200],lw=3)
plt.plot(T3,-np.pi/4-G[199:99:-1],lw=3)
plt.plot(T4,-np.pi/4-G[99::-1],lw=3)
my_y_ticks = [0,-np.pi/4]
plt.yticks(my_y_ticks,('$0$','$-\pi/4$'))
plt.plot(T1[0],G[0],'o',markersize=6,c='r')
plt.plot(T4[-1],G[-1],'*',markersize=10,c='b')
plt.xlabel(r'$\mu s$')
plt.ylabel(r'$\Phi_{2,m}$')
# Out:
# 3723.241248929705 5253.530488448891 119.57887754490409
# 3723.241248929705 5253.530488448891 119.57887754490409
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-3e5fe52ef83e> in <module>
#      28 for i in range(400):
#      29     for j in range(10):
# ---> 30         G[i] = g[j][i] + G[i]
#      31 # plt.plot(*ion_amps.f_modulation())
#      32 plt.figure(figsize=(10,10))
#
# IndexError: invalid index to scalar variable.

# %%
from scipy.optimize import minimize

# %% [markdown]
# ## 相位优化 vs gate time

# %%
N_ions = 10
dipole_strenth = 20
ion_i = 5
ion_j = 4
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)


ion_amps = Ion_Gate(IonChainSetting)

delta0 = 2*np.pi*0.5e6    # drive detuning
u0 = np.average(IonChainSetting.vs_x[-2:])
u = u0 + delta0
T0 = np.array([0.5,0.5])*2*np.pi/delta0/1.5 #
phase0 = np.array([0,0])
A0 = np.array([1,1])

def cal(x):
    u = x[0] + u0
    Tss = x[1:3]
    phases = x[3:5]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases)
    return ion_amps.optimize_value(u,ion_i,ion_j) # Raman laser also on the ion_i and ion_j

p0 = np.concatenate(([delta0],T0, phase0))
result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
                        options={'xtol': 1e-9,'disp': True,
                                'maxiter':10000})
# Out:
# sb
# 30.541453625909824 324.1212988568023 28.52294501514396
# sb
# 26.762133219186193 371.4323503663676 29.162518594754708
# sb
# 15.572812191482793 1425.9472157760906 56.455583413969954
# sb
# 15.572812191490724 1425.947215776451 56.455583413977095
# sb
# 30.394786540387194 323.27858760178486 28.485793199754063
# sb
# 30.14222822344133 322.0457236030223 28.44380407252756
# sb
# 71.31326259209519 417.71423762594566 32.72448988904534
# sb
# 26.36868035862719 282.20004797370837 27.601410248339246
# sb
# 0.2602473211522346 172.58173002321078 22.65274633716701
# sb
# 104.6189981088622 534.0633977190746 36.59184159631634
# sb
# 78.22294984963504 441.1668894352129 33.538414166966454
# sb
# 16.849692255869407 220.06162734180873 24.54465361215391
# sb
# 16.894572703443288 220.36476170088648 24.556137478512372
# sb
# 16.929831504918585 220.5796594281528 24.568042984401377
# sb
# 631.927693951893 1342.221665008148 58.70525841896116
# sb
# 16.03116436802323 253.52502487750644 26.40648407815197
# sb
# 1.0964215141368372 96.69030298608358 17.310296457054008
# sb
# 0.061342445819035384 52.6087098485739 13.718889634247184
# sb
# 1.30514690375437 96.4458547060972 17.261642362702965
# sb
# 0.07512917563144407 79.18211589113082 16.14724771275382
# sb
# 0.20744799410044995 56.34069877084505 14.328348771132289
# sb
# 0.5471843526583301 35.9826840648567 12.479061959557958
# sb
# 0.3090168315725547 18.09985250093682 10.577804682605837
# sb
# 0.12244736397583351 20.384352660499665 10.364948055866414
# sb
# 0.2818661123028416 16.25658191333855 10.175042981700079
# sb
# 0.02980020089332473 7.493152517268916 9.014500267816743
# sb
# 0.07420404561956036 7.852131013345002 8.931646174893721
# sb
# 0.02208639635629772 4.6361974821472725 8.334484363290814
# sb
# 0.0019672834492743545 0.7811856369502572 7.4369487933748335
# sb
# 0.004602666270833389 0.40906665428107547 7.6175342116078
# sb
# 0.027899920675468107 3.8533376057863076 7.533757860106661
# sb
# 0.0036084081974179488 0.5369440209314771 7.784687036877081
# sb
# 0.0022955178603815286 1.7944722644025066 7.212212614741226
# sb
# 0.010977517198616416 3.1997865173645086 7.441983365944536
# sb
# 0.09787825279446104 9.8118973728658 7.5362123629850215
# sb
# 0.004873107767903162 1.4405052169143844 7.910250515070461
# sb
# 0.015728489854273903 4.771153611482898 8.418494752918408
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)


ion_amps = Ion_Gate(IonChainSetting)

u0 = 2*np.pi*2.4e6  
phase0 = np.array([1.6,1.6])
bnds = ((0, None), (0, 0.5), (0, None), (0, None))

def cal(x, args):
    u = x[0] 
    Tss = [x[1]*args,(0.5-x[1])*args]
    phases = x[2:4]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases)
    return ion_amps.optimize_value(u,ion_i,ion_j)[0] # Raman laser also on the ion_i and ion_j

fie_time = np.zeros(50)
G_time = np.zeros(50)

for i,t in enumerate(np.linspace(1,50,50)):
    print('-------------------------------')
    tt = t*1e-6
    p0 = np.concatenate(([u0],[0.25], phase0))
    result = minimize(cal,p0,args=tt,method = 'Nelder-Mead',tol=1e-5,
                            options={'xtol': 1e-9,'disp': True,
                                    'maxiter':10000})
    
    u  = result.x[0]
    Tss = np.array([result.x[1],0.5-result.x[1]]*tt)
    phases0 = result.x[2:4]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases0)

    fie_time[i] = ion_amps.optimize_value(u,ion_i,ion_j)[0]
    G_time[i] = ion_amps.optimize_value(u,ion_i,ion_j)[1]
    print('-------------------------------')
# Out:
# -------------------------------
# 142.0472559069774 830.5018255583133 50.32140310576133
# 0.8417631998525306 394.1375079122345 28.083550968625737
# 142.047255907031 830.5018255584697 50.32140310576607
# 53.763705255312416 374.601837850347 35.76809861276227
# 74.8783089697648 469.1843632940467 41.00223294093824
# 531.6417195737489 2547.812557957313 82.67149453927178
# 283.69613336938716 1314.1838479881822 62.21925599414314
# 141.7194575706764 1526.1793508172016 61.784075488807716
# 77.66699552421528 1163.752800146722 54.716676703403785
# 35.31181404826123 919.4325764106346 46.99584725516606
# 35.31181404826897 919.4325764107352 46.99584725516863
# 2.821167699054042 466.19985846928256 31.85322059646917
# 0.8077493435318502 405.2930641459101 28.217235260738672
# 0.28574499667897346 347.583677867414 25.781916197725582
# 0.08029666485324202 288.9847720196245 22.54071885281915
# 0.09265483867459635 270.0278123674365 21.387687379399
# 0.15286954902830605 231.559634866401 18.889898040034602
# 0.1910057202279272 244.97400897128472 19.305774841072335
# 0.15243569764914025 225.35059407960873 18.533141482559557
# 0.08657820374715115 209.26224203384103 17.663143078471254
# 0.0758045458266456 207.5770266105709 17.295353177627476
# 0.09999810974510687 217.23407010281133 18.604658081269942
# 0.04149340410025049 207.76733740234226 17.421581059001973
# 0.10400419922389142 211.19805559082408 18.58521083388151
# 0.3231918270789311 232.44661194592587 20.54090196188565
# 0.10826125728827699 211.5484333391544 17.61391503636782
# 0.08444962464995155 212.88258324877572 18.436085320487457
# 0.07013330335012179 207.63751820021716 17.442327796944053
# 0.19398506842441662 221.8650597616289 17.820164801552757
# 0.04119041444338661 207.0356791822409 17.77179900591829
# 0.04606815681831428 209.78238936853788 17.664059046979833
# 0.06629256952910817 207.3142088241841 17.47613359773433
# 0.08741564304830993 209.16395485955982 17.769076042792133
# 0.04650554961589794 206.93561928391296 17.3992416904474
# 0.041574006656929674 207.30900198082975 17.570985732294023
# 0.04736981427924822 207.60948158721646 17.899677536695005

#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     630                     # Perform an inside contraction
#     631                     xcc = (1 - psi) * xbar + psi * sim[-1]
# --> 632                     fxcc = func(xcc)
#     633
#     634                     if fxcc < fsim[-1]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# <ipython-input-91-f3fa5456dba8> in cal(x, args)
#      22     Ampss = np.array([1,1])
#      23     ion_amps.setSemiSegments(Tss,Ampss,phases)
# ---> 24     return ion_amps.optimize_value(u,ion_i,ion_j)[0] # Raman laser also on the ion_i and ion_j
#      25
#      26 fie_time = np.zeros(50)
#
# <ipython-input-78-8b15c2ae576f> in optimize_value(self, u, i, j)
#     289             dalpha2 = (np.abs(g_mi)+np.abs(g_mj))*Omega_SDF*np.abs(self.Alpha_f(u,vm,np.pi/2))
#     290             Gphase  = g_mi*g_mj*Omega_SDF**2*self.Geometry_Phase(u,vm)
# --> 291             Gphase_time = g_mi*g_mj*Omega_SDF**2*np.array(self.Geometry_Phase_time(u,vm))
#     292
#     293             G_phase_list.append(Gphase)
#
# <ipython-input-78-8b15c2ae576f> in Geometry_Phase_time(self, u, vm)
#     200                 Phi = Phi_k-Phi_i  # need to check A-B or B-A
#     201
# --> 202                 M_phase = f0_phase(t_i1,t_i,t_k1,t_k,u,vm,Phi)
#     203                 phase_diag =  f1_phase(T_list[:-1],T_list[1:],u,vm)
#     204                 np.fill_diagonal(M_phase, phase_diag)
#
# <lambdifygenerated-31> in _lambdifygenerated(T0, T1, T2, T3, u, v, phi)
#       1 def _lambdifygenerated(T0, T1, T2, T3, u, v, phi):
# ----> 2     return (select([not_equal(u, v),True], [(-u**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + u**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + u**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - u**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi) - 2*u*v*sin(-T0*u + T2*u + phi)*cos(v*(T0 - T2)) + 2*u*v*sin(-T0*u + T3*u + phi)*cos(v*(T0 - T3)) + 2*u*v*sin(-T1*u + T2*u + phi)*cos(v*(T1 - T2)) - 2*u*v*sin(-T1*u + T3*u + phi)*cos(v*(T1 - T3)) - v**2*sin(v*(T0 - T2))*cos(-T0*u + T2*u + phi) + v**2*sin(v*(T0 - T3))*cos(-T0*u + T3*u + phi) + v**2*sin(v*(T1 - T2))*cos(-T1*u + T2*u + phi) - v**2*sin(v*(T1 - T3))*cos(-T1*u + T3*u + phi))/(u**2 - v**2)**2,(1/8)*(-4*T2*v**2*(T0 - T1)*sin(phi) + 4*T3*v**2*(T0 - T1)*sin(phi) + sin(-2*T0*v + 2*T2*v + phi) - sin(-2*T0*v + 2*T3*v + phi) - sin(-2*T1*v + 2*T2*v + phi) + sin(-2*T1*v + 2*T3*v + phi))/v**2], default=numpy.nan))
#
# KeyboardInterrupt:

# %%
N_ions = 10
dipole_strenth = 20
ion_i = 4
ion_j = 5
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
bnds = ((0, 0.5), (0, None), (0, None))

ion_amps = Ion_Gate(IonChainSetting)
u0 = np.average(IonChainSetting.vs_x[-2:])
phase0 = np.array([np.pi/2,np.pi/2])

def cal(x, args):
    u = args[0] 
    Tss = [x[0]*args[1],(0.5-x[0])*args[1]]
    phases = x[1:3]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases)
    return ion_amps.optimize_value(u,ion_i,ion_j)[0] # Raman laser also on the ion_i and ion_j

fie_time_2 = np.zeros(50)
G_time_2 = np.zeros(50)

for i,t in enumerate(np.linspace(1,50,50)):
    print('point%d-------------------------------' %i)
    tt = t*1e-6
    u = 2*np.pi/1.5/tt + u0
    a = [u,tt]
    p0 = np.concatenate(([0.25], phase0))
#     result = minimize(cal,p0,args=a,method = 'SLSQP',bounds=bnds, tol=1e-10,
#                      options={'disp': True, 'iprint': 1, 'eps': 1.4901161193847656e-08,
#                               'maxiter': 500,'xtol': 1e-9})
    result = minimize(cal,p0,args=a,method = 'Nelder-Mead',tol=1e-5,
                            options={'xtol': 1e-9,'disp': True,
                                    'maxiter':10000})

    Tss = np.array([result.x[0]*tt,(0.5-result.x[0])*tt])
    phases0 = result.x[1:3]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases0)

    fie_time_2[i] = ion_amps.optimize_value(u,ion_i,ion_j)[0]
    G_time_2[i] = ion_amps.optimize_value(u,ion_i,ion_j)[1]
    print('point%d-------------------------------' %i)
# Out:
# point0-------------------------------
# 0.16949951819793793 219.7393546811147 17.786029719189493
# 0.16949951819793563 219.73935468111318 17.786029719189433
# 0.19013134126065234 227.63327895218012 18.13651751776425
# 0.08607577587965352 219.4883964057041 18.638384342296224
# 0.07287170324915192 212.99747727312715 18.07394120683919
# 0.038690336763534734 207.71939912484387 18.207707841710786
# 0.041441516662854054 210.0256699514441 18.49933994113782
# 0.07611246416004262 205.13361029735603 19.348923512119654
# 0.3346888057259637 199.67875827595427 20.68936787903805
# 0.4309524907963819 198.17561828565437 19.962047934342614
# 1.030953567295866 200.08837283739598 21.93795085447032
# 1.0504791588257298 197.33373696117383 21.359331371646526
# 4.835293415905933 200.29189335322098 24.730586159830267
# 4.1404069982225815 196.76790707511748 25.432062645588072
# 1.614141403373123 195.568040981002 22.562787306328286
# 1.785928284656888 200.2689851442625 22.32489211114004
# 0.5838375268676178 197.5588079954797 20.88031982840108
# 2.156411558525265 195.7431212272846 23.61535147325877
# 1.6065507986218244 194.69169141610467 23.25841311851227
# 1.983017825522522 193.82603688158818 24.43379514176259
# 6.383737290359848 195.35064508421033 27.483362624834587
# 1.0783230896769938 195.89585566574812 22.053809177817985
# 0.981948929639983 194.31733401166375 22.318688944071653
# 0.5917898765328351 194.24862445243946 21.76987053209425
# 0.8081653330157382 195.3588759340024 23.027052673825263
# 0.7877571091518645 193.1950877958969 24.067816171255306
# 0.48065049436038876 193.5519328873002 25.355308896987456
# 1.1705749550833717 192.1395890118039 23.670062906822235
# 1.2405530180758988 191.92393046977003 24.111148479626124
# 0.21691532020132157 191.98899406264422 22.00297154929141
# 0.08120927968052517 192.38904464273259 20.999195621353053
# 0.4189615346388112 189.43694025299706 24.993986469199395
# 0.12400001325073437 188.3468144066019 27.020703666361484
# 0.10868748531542724 190.72629566733843 24.208639803560892
f = [0.1741129342169883,0.06438900422886479,0.028103689141988852,0.013141232930274215,0.006196486823761181,0.0027993250087670818,0.0011445367130553153,0.000398085813253507,0.00013290964895747897,0.00020112632196257613,0.0003168265475692028,0.00041420705063828945,0.0004704332596786649,0.00047840025454250196,0.0004417300924670901,0.0003709482070508907,0.0002803528874751589,0.00018539258761367944,0.00010050952178303712,3.746834678619181e-05,4.204623115872345e-06,4.211727209684909e-06]
ff = [1-fff for fff in f]
gg = G_time_1[2:24]
t = np.linspace(3,24,22)
fig=plt.figure(figsize=(8,5))

#ax1显示y1  ,ax2显示y2 
ax1=fig.subplots()
ax2=ax1.twinx()    #使用twinx()，得到与ax1 对称的ax2,共用一个x轴，y轴对称（坐标不对称）
ax1.plot(t,ff,'r-')
ax2.plot(t,gg/(2*np.pi*1e6),'b--')
ax1.set_xlabel('gate time ($\mu$s)')
ax1.set_ylabel('Fiedlity')
ax2.set_ylabel(r'$\frac{\Omega}{2\pi}$(MHz)')

plt.savefig('../fig/f_time.pdf')
plt.show()

# %%
plt.figure(figsize=(4,2.5))
plt.plot(t[5:-1],ff[5:-1],c='black',lw=2)
plt.scatter(t[5:-1],ff[5:-1],color='black',marker='^',s=70)
plt.savefig('../fig/f_time_2.pdf')

# %%
ff = [1-fff for fff in fie_time_2[1:25]]
gg = G_time_2[1:25]
t = np.linspace(2,25,24)
fig=plt.figure(figsize=(5,5))

#ax1显示y1  ,ax2显示y2 
ax1=fig.subplots()
ax2=ax1.twinx()    #使用twinx()，得到与ax1 对称的ax2,共用一个x轴，y轴对称（坐标不对称）
ax1.plot(t,ff,'r-')
ax2.plot(t,gg/(2*np.pi*1e6),'b--')
ax1.set_xlabel('gate time ($\mu$s)')
ax1.set_ylabel('Fiedlity')
ax2.set_ylabel(r'$\frac{\Omega}{2\pi}(MHz)$')

plt.show()

# %%
N_ions = 10
dipole_strenth = 20
ion_i = 5
ion_j = 4
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)


ion_amps = Ion_Gate(IonChainSetting)
u0 = np.average(IonChainSetting.vs_x[-2:])
phase0 = np.array([1.6,1.6])

def cal(x, args):
    u = args[0] 
    Tss = [x[0]*args[1],(0.5-x[0])*args[1]]
    phases = x[1:3]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases)
    return ion_amps.optimize_value(u,ion_i,ion_j)[0] # Raman laser also on the ion_i and ion_j

fie_time_2 = np.zeros(50)
G_time_2 = np.zeros(50)

for i,t in enumerate(np.linspace(1,50,50)):
    print('-------------------------------')
    tt = t*1e-6
    u = 2*np.pi/1.5/tt + u0
    a = [u,tt]
    p0 = np.concatenate(([0.25], phase0))
    result = minimize(cal,p0,args=a,method = 'Nelder-Mead',tol=1e-5,
                            options={'xtol': 1e-9,'disp': True,
                                    'maxiter':10000})

    Tss = np.array([result.x[0],0.5-result.x[0]]*tt)
    phases0 = result.x[1:3]
    Ampss = np.array([1,1])
    ion_amps.setSemiSegments(Tss,Ampss,phases0)

    fie_time_2[i] = ion_amps.optimize_value(u,ion_i,ion_j)[0]
    G_time_2[i] = ion_amps.optimize_value(u,ion_i,ion_j)[1]
    print('-------------------------------')

# %% [markdown]
# ## 相位优化 vs 离子链长度

# %%
np.array([0.25,0.25])*1e-6
# Out:
# array([2.5e-07, 2.5e-07])

# %% [markdown]
# # 强度优化

# %% [markdown]
# ## 11 离子

# %%
# dipole on the ion_i and ion_j, then calcaulate the phase gate of the two ions

N_ions = 11
dipole_strenth = 20
ion_i = 5
ion_j = 4
v0 = 2*np.pi*200e3    # v_z = 200Kz
beta=10.0

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
IonChainSetting.Omega_SDF =  70e6 *2 *np.pi # SDF induced Rabi


ion_amps = Ion_Gate(IonChainSetting)


delta = 2*np.pi*0.5e6    # drive detuning
u0= np.average(IonChainSetting.vs_x[-2:])+ delta
T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 #
A0 = np.array([0.05,0.1,0.2,0.5])
phases0 = np.zeros(len(A0))

N_Semi = len(T0)   # total segments is 2*N_semi-1

ion_amps.setSemiSegments(T0,A0,phases0)

# plt.plot(*ion_amps.f_modulation())
plot_traces(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))

# IonChainSetting.vs_x/np.pi/2/1e6
# Out:
# 5.974637961357303

# %% [markdown]
# ###  优化

# %%
def cal(x):
    u = x[0]
    Tss = x[1:1+N_Semi]
    Ampss = x[1+N_Semi:1+2*N_Semi]
    phases0 = np.zeros(len(Ampss))
    ion_amps.setSemiSegments(Tss,Ampss,phases0)
    return ion_amps.optimize_value(u,ion_i,ion_j) # Raman laser also on the ion_i and ion_j

p0 = np.concatenate(([u0],T0, A0))
result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
                        options={'xtol': 1e-9,'disp': True,
                                'maxiter':10000})
# Out:
# 0.047121621562431576 0.4894791221544249 7.256764520135474
# 0.006597732164068657 5.9817912840290255 2.4401819169790047
# 0.04638965263559775 0.46296449699215736 7.2577999504435455
# 0.041420843784873075 0.39282625358690537 7.258604585188505
# 0.1082353012387531 0.13026454881965283 7.22696970002792
# 0.29941153024378375 1.983380681196345 7.313579535227459
# 0.04664459068152537 0.46006539726261364 7.256861699663493
# 0.04514824832816665 0.38705772682214645 7.248605216809847
# 0.03718930257021992 1.191168152415113 7.1912015805306355
# 0.07453818358155319 0.3602265958198759 8.159374959191776
# 0.5462118924921866 0.33311013344618606 5.247691813180421
# 0.8863614561757251 0.9795237001098233 4.424355574366044
# 0.005988761426627598 0.39265929559113216 4.429117555196595
# 0.007709776812648596 0.14439256441150866 3.346152869869468
# 0.36766593372213197 364.46376820153023 26.311632756855087
# 0.5686874663658417 0.5398135726338376 3.6429206059230568
# 0.04808011782543797 0.02316277799414307 4.765650783399683
# 0.05566623170899304 0.05425195528954326 4.391971395884565
# 0.06845626888034936 0.04414758967633422 3.969123942037837
# 0.07882096845353936 0.10877466510444406 3.5125125872781355
# 0.07632537621237523 0.2737696276881669 3.0422160389031108
# 0.02581970245626967 0.6727327341525828 2.2326899217160916
# 0.04132536956700845 0.3628206502768761 2.442474225267266
# 0.011579981742054095 3.6109008562520124 1.7153978723145658
# 0.054797249886804275 0.7379224141709237 2.038035557704057
# 0.0900084068945004 8.14331715176932 1.0231281427066579
# 0.26810553514631863 1.0618409929705757 2.1579433148414617
# 3.3255321840535063e-05 5.6378981966093225e-05 1.509903313490213e-14
# 3.3255321841242106e-05 5.637898196538555e-05 1.509903313490213e-14
# 3.325532184067869e-05 5.637898196594194e-05 2.6645352591003757e-15
# 3.3255321841488274e-05 5.637898196512471e-05 8.881784197001252e-16
# 3.3255321841046604e-05 5.6378981965590677e-05 1.1546319456101628e-14
# 3.325532184039234e-05 5.637898196623863e-05 1.3322676295501878e-14
# 3.3255321841290915e-05 5.637898196533916e-05 8.881784197001252e-16
# 3.325532184119873e-05 5.637898196543484e-05 7.993605777301127e-15
# 3.3255321841473264e-05 5.637898196515772e-05 8.881784197001252e-16
# 3.3255321841281604e-05 5.637898196535278e-05 4.440892098500626e-15
# 3.3255321841353846e-05 5.637898196527041e-05 1.1546319456101628e-14
# Optimization terminated successfully.
#          Current function value: 0.000090
#          Iterations: 2229
#          Function evaluations: 3376

# %%
u  = result.x[0]
Tss = result.x[1:1+N_Semi]
Ampss = result.x[1+N_Semi:1+2*N_Semi]
phases0 = np.zeros(len(Ampss))
ion_amps.setSemiSegments(Tss,Ampss,phases0)

plt.figure(figsize=(6,6))
plot_traces(ion_amps.f_alpha_x(u,ion_i,ion_j,-1,phi0=np.pi/2))
plt.gca().set_aspect('equal', adjustable='box')

# %%
t, y,phase = ion_amps.f_modulation()
t=t/1e-6
plt.plot(t,y)

# %%
result.x
# Out:
# array([3.39844938e+07, 1.34117132e-07, 3.10989994e-07, 4.49236317e-07,
#        1.67515261e-06, 7.36672160e-02, 6.33851803e-02, 2.34211066e-01,
#        3.50321212e-01])

# %%
u0
# Out:
# 30821835.492095202

# %% [markdown]
# ## 100 离子

# %%
# dipole on the ion_i and ion_j, then calcaulate the phase gate of the two ions

N_ions = 100
dipole_strenth = 20
ion_i = 50
ion_j = 51
v0 = 2*np.pi*100e3    # v_z = 200Kz
beta=23.0

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
IonChainSetting.Omega_SDF =  70e6 *2 *np.pi # SDF induced Rabi


ion_amps = Ion_Gate(IonChainSetting)


delta = 2*np.pi*0.5e6    # drive detuning
u0= np.average(IonChainSetting.vs_x[-2:])+ delta
T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 #
A0 = np.array([0.05,0.1,0.2,0.5])
phases0 = np.zeros(len(A0))

N_Semi = len(T0)   # total segments is 2*N_semi-1

ion_amps.setSemiSegments(T0,A0,phases0)

print(min(IonChainSetting.vs_x/2/np.pi/1e6),max(IonChainSetting.vs_z/2/np.pi/1e6))
# plt.plot(*ion_amps.f_modulation())
plot_traces(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))
# Out:
# 6.56971830559486

# %%
def cal(x):
    u = x[0]
    Tss = x[1:1+N_Semi]
    Ampss = x[1+N_Semi:1+2*N_Semi]
    phases0 = np.zeros(len(Ampss))
    ion_amps.setSemiSegments(Tss,Ampss,phases0)
    return ion_amps.optimize_value(u,ion_i,ion_j) # Raman laser also on the ion_i and ion_j

p0 = np.concatenate(([u0],T0, A0))
result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
                        options={'xtol': 1e-9,'disp': True,
                                'maxiter':10000})
# 0.0005825993721583159 0.0016237069565256152 1.1546319456101628e-14
# 0.0005825993720796019 0.0016237069566030278 3.108624468950438e-14
# 0.0005825993718987174 0.0016237069567833153 1.687538997430238e-14
# 0.0005825993720222218 0.0016237069566606306 2.5757174171303632e-14
# 0.0005825993720409653 0.0016237069566401694 3.9968028886505635e-14
# 0.0005825993720699086 0.0016237069566133367 7.37188088351104e-14
# 0.0005825993720363867 0.0016237069566464597 7.37188088351104e-14
# 0.0005825993720988266 0.0016237069565846942 3.108624468950438e-14
# 0.0005825993720799348 0.001623706956603182 6.838973831690964e-14
# 0.0005825993719688584 0.001623706956714562 8.79296635503124e-14
# 0.0005825993721301787 0.0016237069565523533 2.6645352591003757e-15
# 0.000582599372037311 0.0016237069566449706 5.417888360170764e-14
# 0.0005825993720303753 0.0016237069566519989 3.108624468950438e-14
# 0.0005825993720250254 0.001623706956659936 1.021405182655144e-13
# 0.0005825993720593135 0.0016237069566239152 5.950795411990839e-14
# Optimization terminated successfully.
#          Current function value: 0.002206
#          Iterations: 1621
#          Function evaluations: 2551

# %%
u  = result.x[0]
Tss = result.x[1:1+N_Semi]
Ampss = result.x[1+N_Semi:1+2*N_Semi]
phases0 = np.zeros(len(Ampss))
ion_amps.setSemiSegments(Tss,Ampss,phases0)

plt.figure(figsize=(6,6))
plot_traces(ion_amps.f_alpha_x(u,ion_i,ion_j,-1,phi0=np.pi/2))
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## 改变离子间距，优化

# %%
# dipole on the ion_i and ion_j, then calcaulate the phase gate of the two ions

N_ions = 100
dipole_strenth = 20
v0 = 2*np.pi*100e3    # v_z = 200Kz
beta=23.0


ion_i = 40

data = []
for ion_j in range(40,61):
    DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
    IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
    IonChainSetting.Omega_SDF =  70e6 *2 *np.pi # SDF induced Rabi

    ion_amps = Ion_Gate(IonChainSetting)
    
    
    v1,v2 = IonChainSetting.vs_x[-2:]
    print((v2-v1)/2/np.pi)
    delta = 2*np.pi*0.5e6    # drive detuning
    u0= np.average(IonChainSetting.vs_x[-2:])+ delta
    T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 #
    A0 = np.array([0.05,0.1,0.2,0.5])
    phases0 = np.zeros(len(A0))

    N_Semi = len(T0)   # total segments is 2*N_semi-1

    ion_amps.setSemiSegments(T0,A0,phases0)

    p0 = np.concatenate(([u0],T0, A0))
    result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
                            options={'xtol': 1e-9,'disp': True,
                                    'maxiter':10000})
    d = ((ion_i,ion_j), result, ion_amps.dR2,ion_amps.dalpha2,ion_amps.G_phase)
    print('---------------------------------')
    print((ion_i,ion_j))
    print(result)
    data.append(d)

# print(min(IonChainSetting.vs_x/2/np.pi/1e6),max(IonChainSetting.vs_z/2/np.pi/1e6))
# # plt.plot(*ion_amps.f_modulation())
# plot_traces(ion_amps.f_alpha_x(u0,ion_i,ion_j,-1))

# f = open('100 ion i=30,j=31-70,optimize.pkl','wb')
# pl.dump(data,f)
# f.close()
# Out:
# 1342256.6864104215

# %% [markdown]
# # 相位优化

# %% [markdown]
# # 11离子

# %%
import matplotlib.collections as collections

# %%
# dipole on the ion_i and ion_j, then calcaulate the phase gate of the two ions
# parameter dipole strength: in the unit of v_z; beta: trap frequency at racial direction
# delta: the drive frequency of spin-dependent force; u0: 

N_ions = 10
dipole_strenth = 20
ion_i = 5
ion_j = 4
v0 = 2*np.pi*100e3    # v_z = 500Kz
beta = 5

DipoleList = [(ion_i, dipole_strenth),(ion_j,dipole_strenth)] # dipole laser on the ion_i and ion_j
IonChainSetting = IonChain(N_ions,beta,v0,DipoleList)
# IonChainSetting.Omega_SDF =  5e6 *2 *np.pi # SDF induced Rabi


ion_amps = Ion_Gate(IonChainSetting)

# u0= np.average(IonChainSetting.vs_x[-2:])+ delta
# T0 = np.array([0.08,0.2,0.5,1.3])*2*np.pi/delta/1.5 
u0 = 2*np.pi*2.4e6
T0 = np.array([0.6216952,1,2.5])*1e-6
phases0 = np.array([0.1,0.05,0.1])
A0 = np.array([1,1,1])

N_Semi = len(T0)   # total segments is 2*N_semi-1

ion_amps.setSemiSegments(T0,A0,phases0)
Omega_SDF = ion_amps.optimize_value(u0,ion_i,ion_j)[1]*2*np.pi*1e6
# Out:
# 4.271746225425164e-06 1.3261149996469874 3.0720864081322 10

# %%
from scipy.optimize import minimize
def cal(x):
    u = x[0]
    Tss = x[1:1+N_Semi]
    Ampss = x[1+N_Semi:1+2*N_Semi]
    phases0 = x[1+2*N_Semi:1+3*N_Semi]
    ion_amps.setSemiSegments(Tss,Ampss,phases0)
    return ion_amps.optimize_value(u,ion_i,ion_j) # Raman laser also on the ion_i and ion_j

p0 = np.concatenate(([u0],T0, A0,phases0))
result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
                        options={'xtol': 1e-9,'disp': True,
                                'maxiter':10000})
# Out:
# 4.271746225425164e-06 1.3261149996469874 3.0720864081322 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-355a38b05e60> in <module>
#      11 result = minimize(cal,p0,method = 'Nelder-Mead',tol=1e-5,
#      12                         options={'xtol': 1e-9,'disp': True,
# ---> 13                                 'maxiter':10000})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     586                       callback=callback, **options)
#     587     elif meth == 'nelder-mead':
# --> 588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
#     590         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     583
#     584     for k in range(N + 1):
# --> 585         fsim[k] = func(sim[k])
#     586
#     587     ind = numpy.argsort(fsim)
#
# ValueError: setting an array element with a sequence.

# %%
u  = result.x[0]
Tss = result.x[1:1+N_Semi]
Ampss = result.x[1+N_Semi:1+2*N_Semi]
phases0 = result.x[1+2*N_Semi:1+3*N_Semi]
ion_amps.setSemiSegments(Tss,Ampss,phases0)

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plot_traces(ion_amps.f_alpha_x(u,ion_i,ion_j,-1,phi0=np.pi/2))
plt.gca().set_aspect('equal', adjustable='box')
plt.subplot(1,2,2)
t, y, phase = ion_amps.f_modulation()
t=t/1e-6
plt.plot(t,phase)
plt.plot(t,y)
